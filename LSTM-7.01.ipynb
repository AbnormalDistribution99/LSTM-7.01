# %% [markdown]
# ### Loading Data

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

## Data load
weather_data = np.load('inputs_weather_train.npy', allow_pickle=False, fix_imports=True)
other_data = np.load('inputs_others_train.npy', allow_pickle=False, fix_imports=True)
yield_data = np.load('yield_train.npy', fix_imports=True, allow_pickle=False)
clusterID_genotype = np.load('clusterID_genotype.npy')

weather_test_data = np.load('inputs_weather_test.npy', allow_pickle=False, fix_imports=True)
other_test_data = np.load('inputs_others_test.npy', allow_pickle=False, fix_imports=True)


encoder = LabelEncoder()
scaler = MinMaxScaler(feature_range=(0, 1))
other_data[:, 2] = encoder.fit_transform(other_data[:, 2].reshape(-1, 1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
other_data[0]  ## To check the indexing of the loaded data.
# Out:
# array(['3.0', '243.0', '7', '2009.0', '98.0'], dtype='<U32')

# %%
[length, days, prop_num] = weather_data.shape

# main data part
weather_data1 = np.zeros([length, int(days/7), prop_num])
# sum up year data by week
for i in range(length):
    year_data = weather_data[i]
    year_data1 = year_data[0:int(days/7)*7, :]
    year_data2 = year_data1.reshape(int(days/7),7,7)
    year_by_week = year_data2.sum(axis=1)
    weather_data1[i] = year_by_week

weather_data3 = weather_data1.reshape(length, 7 * int(days/7))
weather_df = pd.DataFrame(weather_data3)
other_df = pd.DataFrame(other_data, columns=['MG', 'Genotype_ID', 'State', 'Year', 'Location'])
yield_df = pd.DataFrame(yield_data, columns=['Yield'])

combined_df = pd.concat([weather_df, other_df, yield_df], axis = 1, join = 'inner')

# %%
state = combined_df['State'].values

# %%
type(state)
# Out:
# numpy.ndarray

# %%
state
# Out:
# array(['7', '0', '25', ..., '6', '9', '3'], dtype=object)

# %%
X = combined_df.iloc[:,0:-1].values  # gets all the column except for the last column(yield) 
Y_real = combined_df.iloc[:, -1].values
max_val = np.max(Y_real)
Y = Y_real/max_val     # Scaling the yield data

# %%
X = scaler.fit_transform(X)
X = np.asarray(X).astype(np.float32)

# %%
X[:, -3] = state

# %%
# Splitting into train test 9:1
training_size = int(len(X) * 0.90)  
test_size = len(X) - training_size
X_train, X_test = X[0:training_size], X[training_size:len(X)]
Y_train, Y_test = Y[0:training_size], Y[training_size:len(X)]

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Activation, Dropout, BatchNormalization,Bidirectional
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

def create_model():
    model = Sequential()
    model.add(LSTM(512, return_sequences=True,input_shape=(1,215),activation='tanh')) # input layer with 512 neurons
    model.add(BatchNormalization())    # to normalize the hidden layer of neurons
#     model.add(Dropout(0.1))
    model.add(LSTM(256,return_sequences=True))
    model.add(BatchNormalization()) 
    model.add(Dropout(0.1))          # Dropout layer to prevent overfitting.
    model.add(LSTM(128,return_sequences=False))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(64,activation='sigmoid'))
    model.add(Dropout(0.1))
    model.add(Dense(32,activation='sigmoid'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    model.add(Activation('linear'))
    return model

model = create_model()
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4, epsilon=1e-08)
model.compile(loss='mse', optimizer=optimizer)

checkpoint = ModelCheckpoint(filepath="model.h5",
                             save_weights_only=True,
                             verbose=1, 
                             monitor='val_loss',
                             save_best_only=True, 
                             mode='min') 


X_train = X_train.reshape(X_train.shape[0],1,X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0],1,X_test.shape[1])

model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=200,batch_size=60,callbacks = [checkpoint],shuffle=True)
# Out:
# Epoch 1/200
# 1396/1396 [==============================] - 34s 21ms/step - loss: 0.0152 - val_loss: 0.0086
#
# Epoch 00001: val_loss improved from inf to 0.00863, saving model to model.h5
# Epoch 2/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0100 - val_loss: 0.0067
#
# Epoch 00002: val_loss improved from 0.00863 to 0.00665, saving model to model.h5
# Epoch 3/200
# 1396/1396 [==============================] - 29s 20ms/step - loss: 0.0080 - val_loss: 0.0061
#
# Epoch 00003: val_loss improved from 0.00665 to 0.00613, saving model to model.h5
# Epoch 4/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0070 - val_loss: 0.0056
#
# Epoch 00004: val_loss improved from 0.00613 to 0.00563, saving model to model.h5
# Epoch 5/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0064 - val_loss: 0.0065
#
# Epoch 00005: val_loss did not improve from 0.00563
# Epoch 6/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0060 - val_loss: 0.0059
#
# Epoch 00006: val_loss did not improve from 0.00563
# Epoch 7/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0057 - val_loss: 0.0055
#
# Epoch 00007: val_loss improved from 0.00563 to 0.00549, saving model to model.h5
# Epoch 8/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0055 - val_loss: 0.0053
#
# Epoch 00008: val_loss improved from 0.00549 to 0.00530, saving model to model.h5
# Epoch 9/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0054 - val_loss: 0.0049
#
# Epoch 00009: val_loss improved from 0.00530 to 0.00494, saving model to model.h5
# Epoch 10/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0052 - val_loss: 0.0054
#
# Epoch 00010: val_loss did not improve from 0.00494
# Epoch 11/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0051 - val_loss: 0.0055
#
# Epoch 00011: val_loss did not improve from 0.00494
# Epoch 12/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0050 - val_loss: 0.0062
#
# Epoch 00012: val_loss did not improve from 0.00494
# Epoch 13/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0050 - val_loss: 0.0052
#
# Epoch 00013: val_loss did not improve from 0.00494
# Epoch 14/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0049 - val_loss: 0.0048
#
# Epoch 00014: val_loss improved from 0.00494 to 0.00483, saving model to model.h5
# Epoch 15/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0048 - val_loss: 0.0049
#
# Epoch 00015: val_loss did not improve from 0.00483
# Epoch 16/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0048 - val_loss: 0.0051
#
# Epoch 00016: val_loss did not improve from 0.00483
# Epoch 17/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0048 - val_loss: 0.0044
#
# Epoch 00017: val_loss improved from 0.00483 to 0.00439, saving model to model.h5
# Epoch 18/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0047 - val_loss: 0.0047
#
# Epoch 00018: val_loss did not improve from 0.00439
# Epoch 19/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0047 - val_loss: 0.0054
#
# Epoch 00019: val_loss did not improve from 0.00439
# Epoch 20/200
# 1396/1396 [==============================] - 30s 22ms/step - loss: 0.0047 - val_loss: 0.0044
#
# Epoch 00020: val_loss did not improve from 0.00439
# Epoch 21/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0046 - val_loss: 0.0043
#
# Epoch 00021: val_loss improved from 0.00439 to 0.00434, saving model to model.h5
# Epoch 22/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0046 - val_loss: 0.0044
#
# Epoch 00022: val_loss did not improve from 0.00434
# Epoch 23/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0045 - val_loss: 0.0043
#
# Epoch 00023: val_loss improved from 0.00434 to 0.00433, saving model to model.h5
# Epoch 24/200
# 1396/1396 [==============================] - 32s 23ms/step - loss: 0.0045 - val_loss: 0.0055
#
# Epoch 00024: val_loss did not improve from 0.00433
# Epoch 25/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0045 - val_loss: 0.0046
#
# Epoch 00025: val_loss did not improve from 0.00433
# Epoch 26/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0045 - val_loss: 0.0043
#
# Epoch 00026: val_loss improved from 0.00433 to 0.00429, saving model to model.h5
# Epoch 27/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0044 - val_loss: 0.0045
#
# Epoch 00027: val_loss did not improve from 0.00429
# Epoch 28/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0044 - val_loss: 0.0042
#
# Epoch 00028: val_loss improved from 0.00429 to 0.00424, saving model to model.h5
# Epoch 29/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0044 - val_loss: 0.0045
#
# Epoch 00029: val_loss did not improve from 0.00424
# Epoch 30/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0044 - val_loss: 0.0043
#
# Epoch 00030: val_loss did not improve from 0.00424
# Epoch 31/200
# 1396/1396 [==============================] - 30s 22ms/step - loss: 0.0044 - val_loss: 0.0043
#
# Epoch 00031: val_loss did not improve from 0.00424
# Epoch 32/200
# 1396/1396 [==============================] - 32s 23ms/step - loss: 0.0043 - val_loss: 0.0045
#
# Epoch 00032: val_loss did not improve from 0.00424
# Epoch 33/200
# 1396/1396 [==============================] - 31s 22ms/step - loss: 0.0043 - val_loss: 0.0044
#
# Epoch 00033: val_loss did not improve from 0.00424
# Epoch 34/200
# 1396/1396 [==============================] - 33s 24ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00034: val_loss improved from 0.00424 to 0.00419, saving model to model.h5
# Epoch 35/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0043 - val_loss: 0.0048
#
# Epoch 00035: val_loss did not improve from 0.00419
# Epoch 36/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0043 - val_loss: 0.0044
#
# Epoch 00036: val_loss did not improve from 0.00419
# Epoch 37/200
# 1396/1396 [==============================] - 32s 23ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00037: val_loss improved from 0.00419 to 0.00415, saving model to model.h5
# Epoch 38/200
# 1396/1396 [==============================] - 32s 23ms/step - loss: 0.0042 - val_loss: 0.0050
#
# Epoch 00038: val_loss did not improve from 0.00415
# Epoch 39/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00039: val_loss did not improve from 0.00415
# Epoch 40/200
# 1396/1396 [==============================] - 32s 23ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00040: val_loss did not improve from 0.00415
# Epoch 41/200
# 1396/1396 [==============================] - 31s 22ms/step - loss: 0.0042 - val_loss: 0.0041
#
# Epoch 00041: val_loss improved from 0.00415 to 0.00410, saving model to model.h5
# Epoch 42/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00042: val_loss did not improve from 0.00410
# Epoch 43/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0042 - val_loss: 0.0041
#
# Epoch 00043: val_loss did not improve from 0.00410
# Epoch 44/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0042 - val_loss: 0.0041
#
# Epoch 00044: val_loss did not improve from 0.00410
# Epoch 45/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0042 - val_loss: 0.0046
#
# Epoch 00045: val_loss did not improve from 0.00410
# Epoch 46/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00046: val_loss did not improve from 0.00410
# Epoch 47/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0041 - val_loss: 0.0043
#
# Epoch 00047: val_loss did not improve from 0.00410
# Epoch 48/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00048: val_loss did not improve from 0.00410
# Epoch 49/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00049: val_loss improved from 0.00410 to 0.00410, saving model to model.h5
# Epoch 50/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00050: val_loss improved from 0.00410 to 0.00407, saving model to model.h5
# Epoch 51/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00051: val_loss did not improve from 0.00407
# Epoch 52/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00052: val_loss did not improve from 0.00407
# Epoch 53/200
# 1396/1396 [==============================] - 31s 22ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00053: val_loss did not improve from 0.00407
# Epoch 54/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0041 - val_loss: 0.0043
#
# Epoch 00054: val_loss did not improve from 0.00407
# Epoch 55/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0041 - val_loss: 0.0042
#
# Epoch 00055: val_loss did not improve from 0.00407
# Epoch 56/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00056: val_loss did not improve from 0.00407
# Epoch 57/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00057: val_loss did not improve from 0.00407
# Epoch 58/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00058: val_loss did not improve from 0.00407
# Epoch 59/200
# 1396/1396 [==============================] - 31s 22ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00059: val_loss improved from 0.00407 to 0.00406, saving model to model.h5
# Epoch 60/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00060: val_loss did not improve from 0.00406
# Epoch 61/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00061: val_loss improved from 0.00406 to 0.00406, saving model to model.h5
# Epoch 62/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00062: val_loss did not improve from 0.00406
# Epoch 63/200
# 1396/1396 [==============================] - 29s 20ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00063: val_loss improved from 0.00406 to 0.00405, saving model to model.h5
# Epoch 64/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00064: val_loss improved from 0.00405 to 0.00405, saving model to model.h5
# Epoch 65/200
# 1396/1396 [==============================] - 29s 20ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00065: val_loss improved from 0.00405 to 0.00405, saving model to model.h5
# Epoch 66/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0040 - val_loss: 0.0046
#
# Epoch 00066: val_loss did not improve from 0.00405
# Epoch 67/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0040 - val_loss: 0.0043
#
# Epoch 00067: val_loss did not improve from 0.00405
# Epoch 68/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00068: val_loss did not improve from 0.00405
# Epoch 69/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00069: val_loss did not improve from 0.00405
# Epoch 70/200
# 1396/1396 [==============================] - 29s 20ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00070: val_loss did not improve from 0.00405
# Epoch 71/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00071: val_loss did not improve from 0.00405
# Epoch 72/200
# 1396/1396 [==============================] - 31s 22ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00072: val_loss did not improve from 0.00405
# Epoch 73/200
# 1396/1396 [==============================] - 31s 22ms/step - loss: 0.0040 - val_loss: 0.0042
#
# Epoch 00073: val_loss did not improve from 0.00405
# Epoch 74/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00074: val_loss did not improve from 0.00405
# Epoch 75/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00075: val_loss did not improve from 0.00405
# Epoch 76/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00076: val_loss improved from 0.00405 to 0.00404, saving model to model.h5
# Epoch 77/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0040 - val_loss: 0.0043
#
# Epoch 00077: val_loss did not improve from 0.00404
# Epoch 78/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00078: val_loss did not improve from 0.00404
# Epoch 79/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00079: val_loss did not improve from 0.00404
# Epoch 80/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00080: val_loss did not improve from 0.00404
# Epoch 81/200
# 1396/1396 [==============================] - 30s 22ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00081: val_loss did not improve from 0.00404
# Epoch 82/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00082: val_loss improved from 0.00404 to 0.00403, saving model to model.h5
# Epoch 83/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00083: val_loss did not improve from 0.00403
# Epoch 84/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0040 - val_loss: 0.0041
#
# Epoch 00084: val_loss did not improve from 0.00403
# Epoch 85/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00085: val_loss did not improve from 0.00403
# Epoch 86/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00086: val_loss did not improve from 0.00403
# Epoch 87/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00087: val_loss did not improve from 0.00403
# Epoch 88/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00088: val_loss did not improve from 0.00403
# Epoch 89/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00089: val_loss did not improve from 0.00403
# Epoch 90/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00090: val_loss improved from 0.00403 to 0.00403, saving model to model.h5
# Epoch 91/200
# 1396/1396 [==============================] - 25s 18ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00091: val_loss did not improve from 0.00403
# Epoch 92/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00092: val_loss did not improve from 0.00403
# Epoch 93/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00093: val_loss improved from 0.00403 to 0.00401, saving model to model.h5
# Epoch 94/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00094: val_loss did not improve from 0.00401
# Epoch 95/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00095: val_loss did not improve from 0.00401
# Epoch 96/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00096: val_loss did not improve from 0.00401
# Epoch 97/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00097: val_loss did not improve from 0.00401
# Epoch 98/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00098: val_loss did not improve from 0.00401
# Epoch 99/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00099: val_loss did not improve from 0.00401
# Epoch 100/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00100: val_loss did not improve from 0.00401
# Epoch 101/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00101: val_loss did not improve from 0.00401
# Epoch 102/200
# 1396/1396 [==============================] - 25s 18ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00102: val_loss did not improve from 0.00401
# Epoch 103/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00103: val_loss did not improve from 0.00401
# Epoch 104/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0042
#
# Epoch 00104: val_loss did not improve from 0.00401
# Epoch 105/200
# 1396/1396 [==============================] - 30s 22ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00105: val_loss did not improve from 0.00401
# Epoch 106/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00106: val_loss did not improve from 0.00401
# Epoch 107/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00107: val_loss did not improve from 0.00401
# Epoch 108/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00108: val_loss did not improve from 0.00401
# Epoch 109/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0043
#
# Epoch 00109: val_loss did not improve from 0.00401
# Epoch 110/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00110: val_loss did not improve from 0.00401
# Epoch 111/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00111: val_loss did not improve from 0.00401
# Epoch 112/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00112: val_loss did not improve from 0.00401
# Epoch 113/200
# 1396/1396 [==============================] - 330s 237ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00113: val_loss did not improve from 0.00401
# Epoch 114/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00114: val_loss did not improve from 0.00401
# Epoch 115/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00115: val_loss did not improve from 0.00401
# Epoch 116/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00116: val_loss improved from 0.00401 to 0.00401, saving model to model.h5
# Epoch 117/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00117: val_loss did not improve from 0.00401
# Epoch 118/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0039 - val_loss: 0.0041
#
# Epoch 00118: val_loss did not improve from 0.00401
# Epoch 119/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00119: val_loss did not improve from 0.00401
# Epoch 120/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00120: val_loss did not improve from 0.00401
# Epoch 121/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00121: val_loss did not improve from 0.00401
# Epoch 122/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00122: val_loss did not improve from 0.00401
# Epoch 123/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00123: val_loss did not improve from 0.00401
# Epoch 124/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00124: val_loss did not improve from 0.00401
# Epoch 125/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00125: val_loss did not improve from 0.00401
# Epoch 126/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00126: val_loss did not improve from 0.00401
# Epoch 127/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00127: val_loss did not improve from 0.00401
# Epoch 128/200
# 1396/1396 [==============================] - 29s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00128: val_loss did not improve from 0.00401
# Epoch 129/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00129: val_loss improved from 0.00401 to 0.00400, saving model to model.h5
# Epoch 130/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0042
#
# Epoch 00130: val_loss did not improve from 0.00400
# Epoch 131/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00131: val_loss did not improve from 0.00400
# Epoch 132/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00132: val_loss did not improve from 0.00400
# Epoch 133/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00133: val_loss did not improve from 0.00400
# Epoch 134/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00134: val_loss did not improve from 0.00400
# Epoch 135/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00135: val_loss did not improve from 0.00400
# Epoch 136/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00136: val_loss did not improve from 0.00400
# Epoch 137/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00137: val_loss did not improve from 0.00400
# Epoch 138/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00138: val_loss did not improve from 0.00400
# Epoch 139/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00139: val_loss did not improve from 0.00400
# Epoch 140/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00140: val_loss did not improve from 0.00400
# Epoch 141/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00141: val_loss did not improve from 0.00400
# Epoch 142/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00142: val_loss did not improve from 0.00400
# Epoch 143/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00143: val_loss did not improve from 0.00400
# Epoch 144/200
# 1396/1396 [==============================] - 25s 18ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00144: val_loss did not improve from 0.00400
# Epoch 145/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0038 - val_loss: 0.0042
#
# Epoch 00145: val_loss did not improve from 0.00400
# Epoch 146/200
# 1396/1396 [==============================] - 26s 18ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00146: val_loss did not improve from 0.00400
# Epoch 147/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00147: val_loss did not improve from 0.00400
# Epoch 148/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0038 - val_loss: 0.0042
#
# Epoch 00148: val_loss did not improve from 0.00400
# Epoch 149/200
# 1396/1396 [==============================] - 25s 18ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00149: val_loss did not improve from 0.00400
# Epoch 150/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00150: val_loss did not improve from 0.00400
# Epoch 151/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00151: val_loss did not improve from 0.00400
# Epoch 152/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00152: val_loss did not improve from 0.00400
# Epoch 153/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00153: val_loss did not improve from 0.00400
# Epoch 154/200
# 1396/1396 [==============================] - 3607s 3s/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00154: val_loss did not improve from 0.00400
# Epoch 155/200
# 1396/1396 [==============================] - 30s 22ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00155: val_loss did not improve from 0.00400
# Epoch 156/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00156: val_loss did not improve from 0.00400
# Epoch 157/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00157: val_loss did not improve from 0.00400
# Epoch 158/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00158: val_loss did not improve from 0.00400
# Epoch 159/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00159: val_loss did not improve from 0.00400
# Epoch 160/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00160: val_loss did not improve from 0.00400
# Epoch 161/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00161: val_loss did not improve from 0.00400
# Epoch 162/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00162: val_loss did not improve from 0.00400
# Epoch 163/200
# 1396/1396 [==============================] - 31s 22ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00163: val_loss did not improve from 0.00400
# Epoch 164/200
# 1396/1396 [==============================] - 30s 21ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00164: val_loss did not improve from 0.00400
# Epoch 165/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00165: val_loss did not improve from 0.00400
# Epoch 166/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00166: val_loss did not improve from 0.00400
# Epoch 167/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00167: val_loss did not improve from 0.00400
# Epoch 168/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00168: val_loss did not improve from 0.00400
# Epoch 169/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00169: val_loss did not improve from 0.00400
# Epoch 170/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00170: val_loss did not improve from 0.00400
# Epoch 171/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00171: val_loss did not improve from 0.00400
# Epoch 172/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00172: val_loss did not improve from 0.00400
# Epoch 173/200
# 1396/1396 [==============================] - 32s 23ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00173: val_loss did not improve from 0.00400
# Epoch 174/200
# 1396/1396 [==============================] - 40s 29ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00174: val_loss did not improve from 0.00400
# Epoch 175/200
# 1396/1396 [==============================] - 42s 30ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00175: val_loss did not improve from 0.00400
# Epoch 176/200
# 1396/1396 [==============================] - 569s 408ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00176: val_loss did not improve from 0.00400
# Epoch 177/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00177: val_loss did not improve from 0.00400
# Epoch 178/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0038 - val_loss: 0.0040
#
# Epoch 00178: val_loss did not improve from 0.00400
# Epoch 179/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00179: val_loss did not improve from 0.00400
# Epoch 180/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00180: val_loss did not improve from 0.00400
# Epoch 181/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00181: val_loss did not improve from 0.00400
# Epoch 182/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00182: val_loss did not improve from 0.00400
# Epoch 183/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00183: val_loss did not improve from 0.00400
# Epoch 184/200
# 1396/1396 [==============================] - 26s 18ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00184: val_loss did not improve from 0.00400
# Epoch 185/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00185: val_loss did not improve from 0.00400
# Epoch 186/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0038 - val_loss: 0.0041
#
# Epoch 00186: val_loss did not improve from 0.00400
# Epoch 187/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00187: val_loss did not improve from 0.00400
# Epoch 188/200
# 1396/1396 [==============================] - 26s 19ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00188: val_loss did not improve from 0.00400
# Epoch 189/200
# 1396/1396 [==============================] - 27s 20ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00189: val_loss did not improve from 0.00400
# Epoch 190/200
# 1396/1396 [==============================] - 27s 19ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00190: val_loss did not improve from 0.00400
# Epoch 191/200
# 1396/1396 [==============================] - 28s 20ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00191: val_loss did not improve from 0.00400
# Epoch 192/200
# 1396/1396 [==============================] - 29s 21ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00192: val_loss did not improve from 0.00400
# Epoch 193/200
# 1396/1396 [==============================] - 38s 27ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00193: val_loss did not improve from 0.00400
# Epoch 194/200
# 1396/1396 [==============================] - 32s 23ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00194: val_loss did not improve from 0.00400
# Epoch 195/200
# 1396/1396 [==============================] - 38s 27ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00195: val_loss did not improve from 0.00400
# Epoch 196/200
# 1396/1396 [==============================] - 39s 28ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00196: val_loss did not improve from 0.00400
# Epoch 197/200
# 1396/1396 [==============================] - 39s 28ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00197: val_loss did not improve from 0.00400
# Epoch 198/200
# 1396/1396 [==============================] - 38s 28ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00198: val_loss did not improve from 0.00400
# Epoch 199/200
# 1396/1396 [==============================] - 39s 28ms/step - loss: 0.0037 - val_loss: 0.0040
#
# Epoch 00199: val_loss did not improve from 0.00400
# Epoch 200/200
# 1396/1396 [==============================] - 38s 27ms/step - loss: 0.0037 - val_loss: 0.0041
#
# Epoch 00200: val_loss did not improve from 0.00400

# %%
import tensorflow as tf
from sklearn.metrics import mean_squared_error

model = create_model()
model.compile(optimizer=optimizer, loss= 'mse')
model.build(input_shape = (1,215))
model.load_weights("model.h5")

test_predict=model.predict(X_test)
trainScore = np.sqrt(mean_squared_error(Y_test *max_val, test_predict*max_val))
print ('Testing MSE', trainScore)
# Out:
# Testing MSE 7.10935642240515

# %% [markdown]
# ### Testing Dataset

# %%
[length_test, days_test, prop_num_test] = weather_test_data.shape
weather_test_data1 = np.zeros([length_test, int(days_test/7), prop_num_test])
for i in range(length_test):
    year_data = weather_test_data[i]
    year_data1 = year_data[0:int(days/7)*7, :]
    year_data2 = year_data1.reshape(30,7, prop_num_test)
    year_by_week = year_data2.sum(axis=1)
    weather_test_data1[i] = year_by_week


weather_data3 = weather_test_data1.reshape(length_test, prop_num_test * int(days/7))
weather_test_df = pd.DataFrame(weather_data3)


other_test_df = pd.DataFrame(other_test_data, columns=['MG', 'Genotype_ID', 'State', 'Year', 'Location'])

# %%
other_test_df
# Out:
#         MG Genotype_ID State    Year Location
# 0      3.0      3069.0  "IA"  2010.0     41.0
# 1      4.0      2526.0  "IN"  2004.0    154.0
# 2      3.0       636.0  "IA"  2014.0     41.0
# 3      5.0      1350.0  "MD"  2005.0    113.0
# 4      3.0      2983.0  "IL"  2006.0    148.0
# ...    ...         ...   ...     ...      ...
# 10332  1.0      4511.0  "MI"  2013.0     64.0
# 10333  3.0      5106.0  "NE"  2007.0    136.0
# 10334  2.0      5826.0  "IL"  2008.0    148.0
# 10335  1.0      5466.0  "SD"  2005.0     10.0
# 10336  0.0      3685.0  "ND"  2013.0     31.0
#
# [10337 rows x 5 columns]

# %%
other_test_df["State"] = encoder.transform(other_test_df["State"])

# %%
test_states = other_test_df["State"].values
test_states
# Out:
# array([ 4,  6,  4, ...,  5, 24, 17])

# %%
len(test_states)
# Out:
# 10337

# %%
combined_test_df = pd.concat([weather_test_df, other_test_df], axis = 1, join = 'inner')
X_test = combined_test_df.values

# %%
len(X_test)
# Out:
# 10337

# %%
from sklearn import preprocessing

X_test = scaler.transform(X_test)
X_test = np.asarray(X_test).astype(np.float32)

# %%
X_test[:, -3] = test_states

X_test = X_test.reshape(X_test.shape[0],1,X_test.shape[1])

test_predict=model.predict(X_test)*max_val
np.save("test_predict_new.npy",  test_predict)  # save the new

# %%
np.save("test_predict_new.npy",  test_predict)  # save the new
